# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv('C:/Users/puru3/Desktop/Movie_collection_train.csv',header=0)

# %%
df.describe()
# Out:
#           Collection  Marketin_expense  Production_expense  \
# count     400.000000        400.000000          400.000000
# mean    48646.500000         55.017180           73.832700
# std     18308.499136        119.755634           13.023426
# min     10000.000000         20.126400           55.920000
# 25%     37800.000000         21.321950           63.250000
# 50%     45000.000000         23.214700           69.030000
# 75%     56500.000000         34.638300           82.840000
# max    100000.000000       1799.524000          106.300000
#
#        Multiplex_coverage        Budget  Movie_length  Lead_Actor_Rating  \
# count          400.000000    400.000000    400.000000         400.000000
# mean             0.469881  35197.771537    137.581750           7.810275
# std              0.113920   4075.766926     28.990673           1.088694
# min              0.129000  19781.355000     76.400000           3.840000
# ...

# %%
sns.jointplot(x=df.Marketin_expense,y=df.Collection)

# %%
np.percentile(df.Marketin_expense,[99])[0]
# Out:
# 472.1522199999998

# %%
uv=np.percentile(df.Marketin_expense,[99])[0]

# %%
df[(df.Marketin_expense>uv)]
# Out:
#      Collection  Marketin_expense  Production_expense  Multiplex_coverage  \
# 378       26200           492.964                91.2               0.329
# 380       20800          1799.524                91.2               0.329
# 386       21000           507.876                91.2               0.300
# 398       10000           787.036                91.2               0.307
#
#         Budget  Movie_length  Lead_Actor_Rating  Lead_Actress_rating  \
# 378  35440.900         169.7              9.240                 9.39
# 380  38707.240         165.4              9.170                 9.43
# 386  25841.860         173.5              9.145                 9.32
# 398  30291.415         173.5              9.215                 9.37
#
#      Director_rating  Producer_rating  Critic_rating  Trailer_views  \
# 378            9.235            9.365           6.96         359760
# 380            9.155            9.410           6.96         417588
# ...

# %%
df.Marketin_expense[(df.Marketin_expense>3*uv)]=3*uv
# Out:
# <ipython-input-8-a7d2183313c0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Marketin_expense[(df.Marketin_expense>3*uv)]=3*uv

# %%
df[(df.Marketin_expense>uv)]
# Out:
#      Collection  Marketin_expense  Production_expense  Multiplex_coverage  \
# 378       26200         492.96400                91.2               0.329
# 380       20800        1416.45666                91.2               0.329
# 386       21000         507.87600                91.2               0.300
# 398       10000         787.03600                91.2               0.307
#
#         Budget  Movie_length  Lead_Actor_Rating  Lead_Actress_rating  \
# 378  35440.900         169.7              9.240                 9.39
# 380  38707.240         165.4              9.170                 9.43
# 386  25841.860         173.5              9.145                 9.32
# 398  30291.415         173.5              9.215                 9.37
#
#      Director_rating  Producer_rating  Critic_rating  Trailer_views  \
# 378            9.235            9.365           6.96         359760
# 380            9.155            9.410           6.96         417588
# ...

# %%
sns.jointplot(x=df.Marketin_expense,y=df.Collection)

# %%
df.Marketin_expense=np.log(1+df.Marketin_expense)

# %%
sns.jointplot(x=df.Marketin_expense,y=df.Collection)

# %%
sns.jointplot(x=df.Avg_age_actors,y=df.Collection)

# %%
lv=np.percentile(df.Avg_age_actors,[1])[0]

# %%
lv
# Out:
# 20.0

# %%
df.Avg_age_actors[(df.Avg_age_actors<0.3*lv)]=0.3*lv
# Out:
# <ipython-input-16-a57c7d69c1bf>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Avg_age_actors[(df.Avg_age_actors<0.3*lv)]=0.3*lv

# %%
df[(df.Avg_age_actors<lv)]
# Out:
#      Collection  Marketin_expense  Production_expense  Multiplex_coverage  \
# 213       56200          3.170122               76.18               0.511
#
#         Budget  Movie_length  Lead_Actor_Rating  Lead_Actress_rating  \
# 213  35413.125         105.8              7.945                 8.04
#
#      Director_rating  Producer_rating  Critic_rating  Trailer_views  \
# 213             7.91            8.215           7.28         504226
#
#      Time_taken  Twitter_hastags   Genre  Avg_age_actors MPAA_film_rating  \
# 213      151.24          204.496  Comedy               6               PG
#
#      Num_multiplex 3D_available
# 213            441          YES

# %%
sns.jointplot(x='Avg_age_actors',y='Collection',data=df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Collection           400 non-null    int64
#  1   Marketin_expense     400 non-null    float64
#  2   Production_expense   400 non-null    float64
#  3   Multiplex_coverage   400 non-null    float64
#  4   Budget               400 non-null    float64
#  5   Movie_length         400 non-null    float64
#  6   Lead_Actor_Rating    400 non-null    float64
#  7   Lead_Actress_rating  400 non-null    float64
#  8   Director_rating      400 non-null    float64
#  9   Producer_rating      400 non-null    float64
#  10  Critic_rating        400 non-null    float64
#  11  Trailer_views        400 non-null    int64
#  12  Time_taken           392 non-null    float64
#  13  Twitter_hastags      400 non-null    float64
#  14  Genre                400 non-null    object
# ...

# %%
df=df.fillna(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Collection           400 non-null    int64
#  1   Marketin_expense     400 non-null    float64
#  2   Production_expense   400 non-null    float64
#  3   Multiplex_coverage   400 non-null    float64
#  4   Budget               400 non-null    float64
#  5   Movie_length         400 non-null    float64
#  6   Lead_Actor_Rating    400 non-null    float64
#  7   Lead_Actress_rating  400 non-null    float64
#  8   Director_rating      400 non-null    float64
#  9   Producer_rating      400 non-null    float64
#  10  Critic_rating        400 non-null    float64
#  11  Trailer_views        400 non-null    int64
#  12  Time_taken           400 non-null    float64
#  13  Twitter_hastags      400 non-null    float64
#  14  Genre                400 non-null    object
# ...

# %%
sns.jointplot(x=df.Production_expense,y=df.Collection)

# %%
df.head()
# Out:
#    Collection  Marketin_expense  Production_expense  Multiplex_coverage  \
# 0       48000          3.050523               59.62               0.462
# 1       43200          3.070199               69.14               0.531
# 2       69400          3.070181               69.14               0.531
# 3       66800          3.074885               59.36               0.542
# 4       72400          3.108212               59.36               0.542
#
#       Budget  Movie_length  Lead_Actor_Rating  Lead_Actress_rating  \
# 0  36524.125         138.7              7.825                8.095
# 1  35668.655         152.4              7.505                7.650
# 2  39912.675         134.6              7.485                7.570
# 3  38873.890         119.3              6.895                7.035
# 4  39701.585         127.7              6.920                7.070
#
#    Director_rating  Producer_rating  Critic_rating  Trailer_views  Time_taken  \
# ...

# %%
del df['MPAA_film_rating']

# %%
df.head()
# Out:
#    Collection  Marketin_expense  Production_expense  Multiplex_coverage  \
# 0       48000          3.050523               59.62               0.462
# 1       43200          3.070199               69.14               0.531
# 2       69400          3.070181               69.14               0.531
# 3       66800          3.074885               59.36               0.542
# 4       72400          3.108212               59.36               0.542
#
#       Budget  Movie_length  Lead_Actor_Rating  Lead_Actress_rating  \
# 0  36524.125         138.7              7.825                8.095
# 1  35668.655         152.4              7.505                7.650
# 2  39912.675         134.6              7.485                7.570
# 3  38873.890         119.3              6.895                7.035
# 4  39701.585         127.7              6.920                7.070
#
#    Director_rating  Producer_rating  Critic_rating  Trailer_views  Time_taken  \
# ...

# %%
df['Avg_rating']=(df.Lead_Actor_Rating + df.Lead_Actress_rating + df.Director_rating + df.Producer_rating + df.Critic_rating)/5

# %%
df.head()
# Out:
#    Collection  Marketin_expense  Production_expense  Multiplex_coverage  \
# 0       48000          3.050523               59.62               0.462
# 1       43200          3.070199               69.14               0.531
# 2       69400          3.070181               69.14               0.531
# 3       66800          3.074885               59.36               0.542
# 4       72400          3.108212               59.36               0.542
#
#       Budget  Movie_length  Lead_Actor_Rating  Lead_Actress_rating  \
# 0  36524.125         138.7              7.825                8.095
# 1  35668.655         152.4              7.505                7.650
# 2  39912.675         134.6              7.485                7.570
# 3  38873.890         119.3              6.895                7.035
# 4  39701.585         127.7              6.920                7.070
#
#    Director_rating  Producer_rating  Critic_rating  Trailer_views  Time_taken  \
# ...

# %%
del df['Lead_Actor_Rating']
del df['Lead_Actress_rating']
del df['Director_rating']
del df['Producer_rating']
del df['Critic_rating']

# %%
df.head()
# Out:
#    Collection  Marketin_expense  Production_expense  Multiplex_coverage  \
# 0       48000          3.050523               59.62               0.462
# 1       43200          3.070199               69.14               0.531
# 2       69400          3.070181               69.14               0.531
# 3       66800          3.074885               59.36               0.542
# 4       72400          3.108212               59.36               0.542
#
#       Budget  Movie_length  Trailer_views  Time_taken  Twitter_hastags  \
# 0  36524.125         138.7         527367      109.60          223.840
# 1  35668.655         152.4         494055      146.64          243.456
# 2  39912.675         134.6         547051      147.88         2022.400
# 3  38873.890         119.3         516279      185.36          225.344
# 4  39701.585         127.7         531448      176.48          225.792
#
#       Genre  Avg_age_actors  Num_multiplex 3D_available  Avg_rating
# ...

# %%
df=pd.get_dummies(df)

# %%
df.head()
# Out:
#    Collection  Marketin_expense  Production_expense  Multiplex_coverage  \
# 0       48000          3.050523               59.62               0.462
# 1       43200          3.070199               69.14               0.531
# 2       69400          3.070181               69.14               0.531
# 3       66800          3.074885               59.36               0.542
# 4       72400          3.108212               59.36               0.542
#
#       Budget  Movie_length  Trailer_views  Time_taken  Twitter_hastags  \
# 0  36524.125         138.7         527367      109.60          223.840
# 1  35668.655         152.4         494055      146.64          243.456
# 2  39912.675         134.6         547051      147.88         2022.400
# 3  38873.890         119.3         516279      185.36          225.344
# 4  39701.585         127.7         531448      176.48          225.792
#
#    Avg_age_actors  Num_multiplex  Avg_rating  Genre_Action  Genre_Comedy  \
# ...

# %%
del df['3D_available_NO']

# %%
df.head()
# Out:
#    Collection  Marketin_expense  Production_expense  Multiplex_coverage  \
# 0       48000          3.050523               59.62               0.462
# 1       43200          3.070199               69.14               0.531
# 2       69400          3.070181               69.14               0.531
# 3       66800          3.074885               59.36               0.542
# 4       72400          3.108212               59.36               0.542
#
#       Budget  Movie_length  Trailer_views  Time_taken  Twitter_hastags  \
# 0  36524.125         138.7         527367      109.60          223.840
# 1  35668.655         152.4         494055      146.64          243.456
# 2  39912.675         134.6         547051      147.88         2022.400
# 3  38873.890         119.3         516279      185.36          225.344
# 4  39701.585         127.7         531448      176.48          225.792
#
#    Avg_age_actors  Num_multiplex  Avg_rating  Genre_Action  Genre_Comedy  \
# ...

# %%
df.corr()
# Out:
#                     Collection  Marketin_expense  Production_expense  \
# Collection            1.000000         -0.309777           -0.373947
# Marketin_expense     -0.309777          1.000000            0.616872
# Production_expense   -0.373947          0.616872            1.000000
# Multiplex_coverage    0.303971         -0.709609           -0.747325
# Budget                0.754353         -0.308316           -0.403334
# Movie_length         -0.278718          0.534858            0.609577
# Trailer_views         0.678691         -0.528186           -0.537165
# Time_taken            0.135156          0.044435            0.031240
# Twitter_hastags       0.059405          0.006812           -0.039551
# Avg_age_actors       -0.004951          0.025012            0.028625
# Num_multiplex        -0.272365          0.638300            0.691225
# Avg_rating           -0.060482          0.533056            0.644509
# Genre_Action         -0.061967          0.034775            0.044404
# ...

# %%
import statsmodels.api as sn

# %%
X=sn.add_constant(df['Budget'])

# %%
lm=sn.OLS(df['Collection'],X).fit()

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             Collection   R-squared:                       0.569
# Model:                            OLS   Adj. R-squared:                  0.568
# Method:                 Least Squares   F-statistic:                     525.5
# Date:                Sun, 08 Nov 2020   Prob (F-statistic):           9.43e-75
# Time:                        14:48:29   Log-Likelihood:                -4324.8
# No. Observations:                 400   AIC:                             8654.
# Df Residuals:                     398   BIC:                             8662.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -7.062e+04   5237.404    -13.485      0.000   -8.09e+04   -6.03e+04
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
y=df['Collection']

# %%
x=df[['Budget']]

# %%
lm2=LinearRegression()

# %%
lm2.fit(x,y)
# Out:
# LinearRegression()

# %%
print(lm2.intercept_,lm2.coef_)
# Out:
# -70624.10545910447 [3.388584]

# %%
lm2.predict(x)
# Out:
# array([53140.96012105, 50242.12816678, 64623.34643343, 61103.33620324,
#        63908.05023692, 50411.54042385, 42543.28226225, 45555.05572123,
#        35371.49671304, 42392.6935893 , 49413.89046556, 42486.81150989,
#        40227.98141565, 41357.39646277, 44124.46332822, 39192.68428913,
#        41093.86628511, 42129.16341164, 32077.36949228, 37178.56078843,
#        34223.2580818 , 41658.57380867, 44990.34819767, 38797.38902264,
#        40886.80685981, 34769.14202124, 38797.38902264, 43202.1077064 ,
#        51635.07339156, 55004.4949488 , 36915.03061077, 43672.69730937,
#        41376.22004689, 36689.14760135, 44124.46332822, 41056.21911687,
#        39324.44937796, 39493.86163503, 41677.39739279, 53517.43180342,
#        61592.74939033, 56811.55902419, 45498.58496888, 46289.17550186,
#        43616.22655701, 36331.49950309, 38289.15225143, 42882.10677638,
#        31004.42519751, 34825.6127736 , 41620.92664043, 44482.11142647,
# ...

# %%
sns.jointplot(x='Budget',y='Collection',data=df,kind='reg')

# %%
x_multi=df.drop('Collection',axis=1)

# %%
x_multi.head()
# Out:
#    Marketin_expense  Production_expense  Multiplex_coverage     Budget  \
# 0          3.050523               59.62               0.462  36524.125
# 1          3.070199               69.14               0.531  35668.655
# 2          3.070181               69.14               0.531  39912.675
# 3          3.074885               59.36               0.542  38873.890
# 4          3.108212               59.36               0.542  39701.585
#
#    Movie_length  Trailer_views  Time_taken  Twitter_hastags  Avg_age_actors  \
# 0         138.7         527367      109.60          223.840              23
# 1         152.4         494055      146.64          243.456              42
# 2         134.6         547051      147.88         2022.400              38
# 3         119.3         516279      185.36          225.344              45
# 4         127.7         531448      176.48          225.792              55
#
#    Num_multiplex  Avg_rating  Genre_Action  Genre_Comedy  Genre_Drama  \
# ...

# %%
y_multi=df['Collection']

# %%
x_multi_cons=sn.add_constant(x_multi)

# %%
x_multi_cons.head()
# Out:
#    const  Marketin_expense  Production_expense  Multiplex_coverage     Budget  \
# 0    1.0          3.050523               59.62               0.462  36524.125
# 1    1.0          3.070199               69.14               0.531  35668.655
# 2    1.0          3.070181               69.14               0.531  39912.675
# 3    1.0          3.074885               59.36               0.542  38873.890
# 4    1.0          3.108212               59.36               0.542  39701.585
#
#    Movie_length  Trailer_views  Time_taken  Twitter_hastags  Avg_age_actors  \
# 0         138.7         527367      109.60          223.840              23
# 1         152.4         494055      146.64          243.456              42
# 2         134.6         547051      147.88         2022.400              38
# 3         119.3         516279      185.36          225.344              45
# 4         127.7         531448      176.48          225.792              55
#
# ...

# %%
lm_multi=sn.OLS(y_multi,x_multi_cons).fit()

# %%
lm_multi.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             Collection   R-squared:                       0.685
# Model:                            OLS   Adj. R-squared:                  0.673
# Method:                 Least Squares   F-statistic:                     55.66
# Date:                Sun, 08 Nov 2020   Prob (F-statistic):           1.76e-86
# Time:                        14:59:36   Log-Likelihood:                -4262.1
# No. Observations:                 400   AIC:                             8556.
# Df Residuals:                     384   BIC:                             8620.
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# ...

# %%
lm3=LinearRegression()

# %%
lm3.fit(x_multi,y_multi)
# Out:
# LinearRegression()

# %%
print(lm3.intercept_,lm3.coef_)
# Out:
# -138806.5468269312 [ 7.35305765e+02 -1.05453240e+02  2.52951652e+04  2.18982575e+00
#  -5.70291464e+01  1.02116985e-01  2.02395560e+01  2.63760893e+00
#   5.13468923e+01  1.67207110e+01  6.08050845e+03 -2.97142882e+03
#   1.13734247e+03  1.96448772e+03 -1.30401376e+02  2.36253104e+03]
